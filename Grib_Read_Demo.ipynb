# %% [markdown]
# # MMM-Py grib2 format mosaic reading demonstration

# %% [markdown]
# The NOAA MRMS mosaics recently changed format (AGAIN!), so MMM-Py has been updated to account for this. As of v1.4, MMM-Py can read MRMS grib2 files and populate its MosaicTile as before. The way the grib files are arranged is every altitude slice is its own separate file. This has pluses (smaller size per file, no more regional tiles, can throw out unnecessary altitudes) and minuses (33 files per time step!). The nice thing about keeping it in the MosaicTile framework is we still have access to its subsection() and write_mrms_binary() methods. So if needed we can cut down the size of our domain and write out a single file that describes it.

# %%
import numpy as np
import matplotlib.pyplot as plt
import glob
import mmmpy
# %matplotlib inline

# %%
BASE_PATH = '/Users/tjlang/Documents/Python/mmmpy'
TMPDIR = BASE_PATH + '/tmpdir/'
WGRIB2_PATH = BASE_PATH + '/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/'
GRIB_PATH = BASE_PATH + '/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/'
gf = glob.glob(GRIB_PATH+'*.grib2')

# %% [markdown]
# After defining where we can find everything, we can now pass a list of grib2 files to MMM-Py's MosaicTile class so that it can read them and populate the necessary attributes. What happens is that MMM-Py uses the os module to call MRMS-modfied wgrib2 to convert grib2 files to netCDFs that are easier to read. Thus, you need to install the MRMS-modifed wgrib2 package, from here: ftp://ftp.nssl.noaa.gov/projects/MRMS/GRIB2_DECODERS/MRMS_modified_wgrib2_v2.0.1-selectfiles.tgz
#
# At some point I hope to get the GRIB_API library updated with the MRMS changes so that we can use pygrib module.

# %%
tile = mmmpy.MosaicTile(filename=gf, verbose=True, wgrib2_path=WGRIB2_PATH, nc_path=TMPDIR,
                        wgrib2_name='wgrib2')
# Out:
# ********************
# read_mosaic_grib():
# >>>>  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_00.50_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_00.50_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_00.75_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_00.75_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_01.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_01.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_01.25_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_01.25_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_01.50_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_01.50_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_01.75_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_01.75_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_02.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_02.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_02.25_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_02.25_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_02.50_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_02.50_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_02.75_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_02.75_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_03.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_03.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_03.50_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_03.50_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_04.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_04.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_04.50_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_04.50_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_05.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_05.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_05.50_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_05.50_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_06.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_06.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_06.50_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_06.50_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_07.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_07.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_07.50_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_07.50_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_08.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_08.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_08.50_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_08.50_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_09.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_09.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_10.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_10.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_11.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_11.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_12.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_12.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_13.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_13.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_14.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_14.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_15.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_15.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_16.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_16.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_17.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_17.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_18.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_18.00_20141208-120035.grib2.nc
# >>>>
#  /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_modified_wgrib2_v2.0.1/wgrib2/wgrib2 /Users/tjlang/Documents/Python/mmmpy/MRMSupdates2015/MRMS_GRIB2_SAMPLE-reflectivity_3d_plus/MRMS_MergedReflectivityQC_19.00_20141208-120035.grib2 -netcdf /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_19.00_20141208-120035.grib2.nc
# MosaicGrib:
#  53.6552960873 seconds to run
# ********************

# %% [markdown]
# Oof, that took a while. But look at it this way. We just read in a full 3D mosaic that covers the CONUS. In terms of overall time, to do the same from gzipped MRMS binaries and then call mmmpy.stich_mosaic_tiles() is not far off.
#
# The keywords above tell MosaicTile how to find wgrib2 and where to put the intermediary netCDFs. There are default values in mmmpy.py that you can change to match your setup, so you don't need to do this all the time.

# %% [markdown]
# <hr>

# %% [markdown]
# Now, the MosaicDisplay class has been recently added to MMM-Py. This consolidates all the plotting methods into a different class, thereby simplifying MosaicTile. However, this adds an additional step. On the plus side, it is now easier to create custom multi-panel plots.

# %%
display = mmmpy.MosaicDisplay(tile)
fig = plt.figure(figsize=(8,14))
ax1 = fig.add_subplot(211)
display.plot_horiz()
ax2 = fig.add_subplot(212)
display.plot_horiz(level=4)

# %%
display.plot_vert(lat=45, xrange=[-95,-85])

# %%
display.three_panel_plot(lat=42.9, lon=-89, latrange=[40,50], lonrange=[-92,-82], 
                         parallels=2, meridians=2)

# %% [markdown]
# You can also read gzipped grib2s, and you don't need to keep the intermediary netCDFs if you don't want to. Plus, you can read only a subset of the files for each time step, to create a coarser-resolution MosaicTile. This can also speed up the read time if you are only interested in certain vertical levels. The default is to not output a bunch of text (verbose=False).

# %%
path = '/Users/tjlang/Documents/Python/mmmpy/mosaics_gribs/'
files = glob.glob(path+'*')
print files[0]
tile = mmmpy.MosaicTile(filename=files[::2], keep_nc=False)
# Out:
# /Users/tjlang/Documents/Python/mmmpy/mosaics_gribs/MergedRefl_20150217_235829_00.50.grib2.gz

# %%
print tile.Height
# Out:
# [  0.5   1.    1.5   2.    2.5   3.    4.    5.    6.    7.    8.    9.
#   11.   13.   15.   17.   19. ]

# %% [markdown]
# See? Way fewer than 33 levels now.

# %%
display = mmmpy.MosaicDisplay(tile)
display.plot_horiz()

# %% [markdown]
# Now, if you want you can also read the intermediary netCDFs if they've already been created and kept. This skips the wgrib2 stuff. You can also just pass MosaicTile a single file, so you just get a single vertical level.

# %%
ncfiles = glob.glob(TMPDIR+'*.nc')
print ncfiles[0]
test = mmmpy.MosaicTile(ncfiles[0])
# Out:
# /Users/tjlang/Documents/Python/mmmpy/tmpdir/MRMS_MergedReflectivityQC_00.50_20141208-120035.grib2.nc

# %%
dis = mmmpy.MosaicDisplay(test)
dis.plot_horiz(level=5, verbose=True)
# Out:
# ********************
# plot_horiz():
# Executing plot
# Attempting to plot cross-section thru 5 km MSL
# Actually taking cross-section thru 0.5 km MSL
# ********************

# %% [markdown]
# Note how only the 0.5-km file was read. So that is all it can plot.
